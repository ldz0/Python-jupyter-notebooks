# %% [markdown]
# # 模拟Ajax爬取微博内容

# %%
import requests
from urllib.parse import urlencode
from pyquery import PyQuery as pq
from pymongo import MongoClient

base_url = 'https://m.weibo.cn/api/container/getIndex?'
headers = {
    'Host': 'm.weibo.cn',
    'Referer': 'https://m.weibo.cn/u/5318584155',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
}
client = MongoClient()
db = client['weibo']
collection = db['weibo']
max_page = 10


def get_page(page):
    params = {
        'type': 'uid',
        'value': '5318584155',
        'containerid': '1076035318584155',
        'page': page
    }
    url = base_url + urlencode(params)
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json(), page
    except requests.ConnectionError as e:
        print('Error', e.args)


def parse_page(json, page: int):
    if json:
        items = json.get('data').get('cards')
        for index, item in enumerate(items):
            if page == 1 and index == 1:
                continue
            else:
                item = item.get('mblog')
                weibo = {}
                weibo['id'] = item.get('id')
                weibo['text'] = pq(item.get('text')).text()
                weibo['attitudes'] = item.get('attitudes_count')
                weibo['comments'] = item.get('comments_count')
                weibo['reposts'] = item.get('reposts_count')
                yield weibo


def save_to_mongo(result):
    if collection.insert(result):
        print('Saved to Mongo')


if __name__ == '__main__':
    for page in range(1, max_page + 1):
        json = get_page(page)
        results = parse_page(*json)
        for result in results:
            print(result)
            save_to_mongo(result)
# Out:
# {'id': '4274822886004699', 'text': '杨哥好样的！@孙杨\n🇨🇳🇨🇳🇨🇳🇨🇳🇨🇳🇨🇳🇨🇳\nOne more！', 'attitudes': 2755, 'comments': 186, 'reposts': 22}
# Saved to Mongo
# {'id': '4274199671348477', 'text': '好运！[加油][加油][加油] 印度尼西亚·雅加达', 'attitudes': 7580, 'comments': 817, 'reposts': 363}
# Saved to Mongo
# {'id': '4273751959175493', 'text': '我们尽力而为！哈哈', 'attitudes': 1173, 'comments': 107, 'reposts': 32}
# Saved to Mongo
# {'id': '4273747814820730', 'text': '满分一百，给你俩98！剩下你俩一人扣一分，怕你俩骄傲！哈哈哈哈哈哈哈。', 'attitudes': 665, 'comments': 50, 'reposts': 9}
# Saved to Mongo
# {'id': '4273721906120907', 'text': '哈哈哈好啊，到时候就给你来个帅气暴扣💪💪💪', 'attitudes': 865, 'comments': 85, 'reposts': 19}
# Saved to Mongo
# {'id': '4273286085581475', 'text': '谁干的来出来！哈哈哈 ！不过我将以此为目标！继续努力！继续加油！中国队！🇨🇳', 'attitudes': 9198, 'comments': 807, 'reposts': 221}
# Saved to Mongo
# {'id': '4270842244363593', 'text': '“每个人心目中都有个珠穆朗玛峰，定了多少高度的目标，就要为目标而努力。生活不仅是篮球，现在只要努力，结果已经不重要了。”—谢谢@王石 大师的智慧，我抄下来也愿与所有人共勉之。', 'attitudes': 2803, 'comments': 242, 'reposts': 72}
# Saved to Mongo
# {'id': '4270809877029608', 'text': '尽管扣，谁能扣赢穿着HYPERDUNK X的我？发布你们的挑战视频，证明你们的实力，我们会选出最帅的那位送上惊喜！穿上HYPERDUNK X给加分哦： 网页链接 @NikeBasketball #HYPERDUNK跃动挑战#\n\n现在点名@王哲林Change @GuangDong-赵睿 你们俩让我和 @丁彦雨航 开开眼呗～ ...全文', 'attitudes': 1839, 'comments': 310, 'reposts': 59}
# Saved to Mongo
# {'id': '4270714842101613', 'text': '#北京奥运十年# 那年夏天，中国男篮主场迎战美国男篮。那年夏天，中国代表团豪取51枚奥运金牌。那一年我只有12岁，却也因此经历了一个心潮澎湃、如痴如醉的夏天。十年了，如今我在海外打球，最能深刻地感受到中国体育的强盛，带给中国人的自信和自豪。现在算起两年，雅加达亚运会、中国男篮世界杯、东 ...全文', 'attitudes': 6471, 'comments': 485, 'reposts': 358}
# Saved to Mongo
# {'id': '4270485208220421', 'text': '视频彩蛋一不小心暴露了我的小紧张。想要好的表现，离不开日常的训练，Keep 的篮球课程很专业，可以让你在球场上更厉害！', 'attitudes': 2509, 'comments': 313, 'reposts': 313}
# Saved to Mongo
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# {'id': '4268280581100141', 'text': '一直以来都有军人梦，每次看军人题材的电视剧都会热血沸腾热泪盈眶。致敬！！！', 'attitudes': 1695, 'comments': 129, 'reposts': 42}
# Saved to Mongo
# {'id': '4265589755199268', 'text': '🇨🇳[加油][加油]', 'attitudes': 7214, 'comments': 749, 'reposts': 182}
# Saved to Mongo
# {'id': '4265257083465427', 'text': '剧透一小波！', 'attitudes': 4474, 'comments': 467, 'reposts': 49}
# Saved to Mongo
# {'id': '4264090354317263', 'text': '我来了！ 北京·北京首都国际机场(商务中心)', 'attitudes': 6340, 'comments': 720, 'reposts': 116}
# Saved to Mongo
# {'id': '4262191005187600', 'text': '哦哟！太厉害了！！精彩精彩！！', 'attitudes': 2236, 'comments': 169, 'reposts': 10}
# Saved to Mongo
# {'id': '4259852026765832', 'text': '@阿不都沙拉木14 #童年照相馆#', 'attitudes': 6732, 'comments': 648, 'reposts': 147}
# Saved to Mongo
# {'id': '4258759636979095', 'text': '给自己加个油！👏👏👏', 'attitudes': 5216, 'comments': 669, 'reposts': 74}
# Saved to Mongo
# {'id': '4257598767318668', 'text': '这玩意咬人不，想给它送回湖边！', 'attitudes': 2965, 'comments': 304, 'reposts': 30}
# Saved to Mongo
# {'id': '4255793492850699', 'text': '好久没来和大伙儿唠了，实在是最近练得有点狠了，每天都累到想吐，就没写了。今天赶紧续上，和大家分享一下目前我的情况。 《周·记》', 'attitudes': 4437, 'comments': 958, 'reposts': 218}
# Saved to Mongo
# {'id': '4255269104269261', 'text': '@JamesHarden 祝贺大哥拿到MVP，还有@火箭经理莫雷DarylMorey 领导MVP！', 'attitudes': 3642, 'comments': 262, 'reposts': 67}
# Saved to Mongo
# {'id': '4254710045230749', 'text': '[加油][加油] 周小七呦的秒拍视频', 'attitudes': 3615, 'comments': 789, 'reposts': 99}
# Saved to Mongo
# {'id': '4246046924337987', 'text': '今天你过节吗？#童年照相馆#', 'attitudes': 6360, 'comments': 661, 'reposts': 97}
# Saved to Mongo
# {'id': '4243169392609377', 'text': '有家人自远方来，不亦乐乎！！', 'attitudes': 8016, 'comments': 611, 'reposts': 147}
# Saved to Mongo
# {'id': '4242670110390804', 'text': 'ci.ci@丁彦雨航 @睢冉V5 周小七呦的秒拍视频', 'attitudes': 2789, 'comments': 199, 'reposts': 47}
# {'id': '4208019141258396', 'text': "Thanks bro! ! Very fortunate to have you as one of my U.S family members. Let's 狗 rockets in the year of dog. Run as one! P.S. Your Chinese pronunciation is perfect!", 'attitudes': 2272, 'comments': 192, 'reposts': 28}
# Saved to Mongo
# {'id': '4207678018168513', 'text': '#晒年味# 亲友团聚合家欢，金狗报喜好运来！大家好，我是周琦，我在休斯敦，此刻正在包饺子，给我一个 #中国赞# 吧！虽然和北京有14个小时时差，但过年的仪式感不能少。吃饺子、看 #春晚# ，给全国人民拜年了！祝大家狗年行大运，狗粮撒满天，红包旺旺旺！', 'attitudes': 9834, 'comments': 695, 'reposts': 102}
# Saved to Mongo
# {'id': '4196968529925414', 'text': '2017年，打了CBA的总决赛，进了NBA，加入了火箭队也认识了我登哥。\n这一年被人夸，也被人骂，也开始了身处异乡的生活。早上一睁眼收到的全是祝福，谢谢大家这一年对我的包容和支持，每次比赛你们在场边的呐喊是我对篮球疯狂的源头。总有人跟我说“周琦，别回来了”，其实我想回家，可我更想打的球再好 ...全文', 'attitudes': 18950, 'comments': 3874, 'reposts': 645}
# Saved to Mongo
# {'id': '4196612336648767', 'text': '祝你生日快乐', 'attitudes': 5750, 'comments': 1622, 'reposts': 325}
# Saved to Mongo
# {'id': '4191556309579813', 'text': '2018，新年快乐！', 'attitudes': 4361, 'comments': 1173, 'reposts': 82}
# Saved to Mongo
# {'id': '4188411688282489', 'text': '球队圣诞节为当地社区的小朋友送温暖！！', 'attitudes': 7926, 'comments': 1041, 'reposts': 75}
# Saved to Mongo
# {'id': '4184620319053121', 'text': '勿忘国耻，我辈自强！', 'attitudes': 2211, 'comments': 250, 'reposts': 36}
# Saved to Mongo
# {'id': '4178527961895436', 'text': '666，走一波！\n一排红厉害，后面的一排黑更猛！', 'attitudes': 5740, 'comments': 384, 'reposts': 34}
# Saved to Mongo
# {'id': '4177446880721774', 'text': '听说有三种颜色？', 'attitudes': 3036, 'comments': 215, 'reposts': 170}
# Saved to Mongo
# {'id': '4177230374483975', 'text': '#感恩节#感恩大家一直以来的支持和陪伴，贼累但是贼高兴，继续努力[加油][加油][加油]', 'attitudes': 12571, 'comments': 1691, 'reposts': 264}
# Saved to Mongo
# {'id': '4171054215943865', 'text': '登哥炸裂全场', 'attitudes': 5688, 'comments': 915, 'reposts': 139}
# Saved to Mongo
# {'id': '4169602482873471', 'text': '万里长征第一步，还有很长的路要走！跟着大哥，继续加油！🚀🚀🚀', 'attitudes': 32440, 'comments': 2695, 'reposts': 972}
# Saved to Mongo
# {'id': '4168161861223023', 'text': '#当出手，绝不让# 与我篮球梦一起前行的是你们的鼓励！谢谢大家支持💪💪💪', 'attitudes': 5246, 'comments': 556, 'reposts': 592}
# Saved to Mongo
# {'id': '4165613410574514', 'text': 'Run as one[加油]', 'attitudes': 13182, 'comments': 1133, 'reposts': 348}
# Saved to Mongo
# {'id': '4159129263952396', 'text': '人在异乡为异客，每逢佳节倍思亲，一刷朋友圈全是发吃的拉仇恨 想念大月饼，大闸蟹 祝大家中秋快乐，阖家团圆', 'attitudes': 8923, 'comments': 953, 'reposts': 61}
# {'id': '4128289352569491', 'text': '@睢冉V5 差个你。', 'attitudes': 6876, 'comments': 682, 'reposts': 180}
# Saved to Mongo
# {'id': '4126762885202575', 'text': '篮球一直赋予着我快乐和希望，这一刻，我更体会到那是怎样一种眷顾。\n诚挚感谢火箭队为我提供了在NBA打球的宝贵机会，帮助我实现了自儿时便开始勾画的梦想。休斯敦火箭队是我的中国前辈姚明奋力拼搏、证明自己以及证明中国篮球的地方，能够追随他的足迹来到这里，我感到无比荣幸的同时，也深知自己即刻 ...全文', 'attitudes': 17515, 'comments': 3027, 'reposts': 1618}
# Saved to Mongo
# {'id': '4106484474550978', 'text': 'Run As One！@休斯敦火箭', 'attitudes': 5458, 'comments': 1041, 'reposts': 206}
# Saved to Mongo
# {'id': '4104325464220355', 'text': '微博视频 .', 'attitudes': 2721, 'comments': 503, 'reposts': 71}
# Saved to Mongo
# {'id': '4104207756135632', 'text': '', 'attitudes': 1232, 'comments': 77, 'reposts': 128}
# Saved to Mongo
# {'id': '4101133846280874', 'text': '据知情人士透露。我要走了。', 'attitudes': 4413, 'comments': 1322, 'reposts': 158}
# Saved to Mongo
# {'id': '4100526327088808', 'text': '又当了次少先队员。感觉真好。', 'attitudes': 3413, 'comments': 224, 'reposts': 22}
# Saved to Mongo
# {'id': '4095801350726774', 'text': '来来来，感受一下飞人的小白鞋🏀🏀🏀满满的活力！\n#纯白当道##PureMoney#', 'attitudes': 2321, 'comments': 219, 'reposts': 13}
# Saved to Mongo
# {'id': '4094944429642750', 'text': '除了CBA冠军，又收到了 @StephenCurry 送给我的这台#vivo 库里定制版Xplay6# 蓝黄经典，感受到了传奇30赛场上的爆发力，谢谢。', 'attitudes': 4922, 'comments': 596, 'reposts': 76}
# Saved to Mongo
# {'id': '4094272292847662', 'text': '分享视频 秒拍视频 .', 'attitudes': 2612, 'comments': 259, 'reposts': 142}
# Saved to Mongo
# {'id': '4094264462282583', 'text': '秒拍视频 .', 'attitudes': 4042, 'comments': 353, 'reposts': 147}
# Saved to Mongo
# {'id': '4094039291259663', 'text': '', 'attitudes': 2725, 'comments': 366, 'reposts': 29}
# Saved to Mongo
# {'id': '4094030368862199', 'text': '赢了！新疆是冠军🏆！但新疆值得更多！感恩新疆，也感恩伟大的对手广东，感恩所有真正爱护中国篮球的兄弟姐妹们。CBA，会更牛！', 'attitudes': 11016, 'comments': 1298, 'reposts': 206}
# Saved to Mongo
# {'id': '4091332576628007', 'text': '咆哮呐喊不如火力全开 #下个我上', 'attitudes': 4246, 'comments': 1119, 'reposts': 107}
# Saved to Mongo
# {'id': '4088588944052819', 'text': '🇨🇳牛。', 'attitudes': 5941, 'comments': 368, 'reposts': 64}
# Saved to Mongo
# {'id': '4087162473260165', 'text': '没有伟大的对手，就没有伟大的比赛，感谢辽宁。所有的这一切都值得珍惜，三年，总决赛我们来了。@赵继伟PG 兄弟不哭，全运会我们一起走。', 'attitudes': 5697, 'comments': 1141, 'reposts': 176}
# Saved to Mongo
# {'id': '4081344801596781', 'text': '总算是对得起我这只脚啦。', 'attitudes': 3624, 'comments': 1538, 'reposts': 59}
# Saved to Mongo
# {'id': '4080214063441823', 'text': '祝贺神丁！', 'attitudes': 2116, 'comments': 154, 'reposts': 20}
# Saved to Mongo
# {'id': '4079823653329312', 'text': '感谢大家关心。。。我很好！', 'attitudes': 3067, 'comments': 814, 'reposts': 65}
# Saved to Mongo
# {'id': '4074025133167558', 'text': '今晚你是吃汤圆还是元宵？舞狮子、耍龙灯、踩高跷、吃元宵、猜灯谜、划旱船，你们都怎么庆祝？祝大家元宵节快乐。', 'attitudes': 2617, 'comments': 392, 'reposts': 27}
# Saved to Mongo
# {'id': '4073201732086768', 'text': '充分尊重宋延平、吕文、杨鹏三位裁判老师的临场裁判，昨天我的行为的确不对。同时，要向中国篮协、CBA联赛、新疆广汇、四川男篮以及所有球迷道歉，因为我的行为影响了CBA观赏度。对不起。', 'attitudes': 5448, 'comments': 2564, 'reposts': 286}
# Saved to Mongo
# {'id': '4069305417275204', 'text': '大年初二。二到家！', 'attitudes': 3323, 'comments': 381, 'reposts': 30}
# Saved to Mongo
# {'id': '4068682210975194', 'text': '哈哈哈。来，放烟火。 秒拍视频 .', 'attitudes': 1716, 'comments': 184, 'reposts': 10}
# Saved to Mongo
# {'id': '4068614124561671', 'text': '祝大家新年快乐，心想事成。哈哈。放烟花啦，南来的北往的，一起放烟花了。哈哈哈', 'attitudes': 3316, 'comments': 458, 'reposts': 48}
# Saved to Mongo
# {'id': '4061412848016043', 'text': '就你了。调教的很不错。奖金你1我9。', 'attitudes': 2225, 'comments': 281, 'reposts': 26}
# Saved to Mongo
# {'id': '4059230774336125', 'text': '这里是红山！南京分店。', 'attitudes': 2257, 'comments': 259, 'reposts': 19}
# Saved to Mongo
# {'id': '4058899231888656', 'text': '2零壹6、an。2017好运！', 'attitudes': 2886, 'comments': 323, 'reposts': 37}
# Saved to Mongo
# {'id': '4054163388201472', 'text': '在这大雾霾的天气，你们把这里变成红山！你们是我们的最佳第六人。感谢有你们。', 'attitudes': 2692, 'comments': 379, 'reposts': 65}
# Saved to Mongo
# {'id': '4053049045568238', 'text': '来到我滴哥的地盘。@睢冉V5', 'attitudes': 2062, 'comments': 220, 'reposts': 16}
# Saved to Mongo
# {'id': '4036421302215996', 'text': '今天在赛场被告知，如果我不穿赞助商的鞋就要判我技术犯规，然后被禁赛。我为什么被剥夺了穿自己鞋的资格，到底谁可以来保护球员的利益？受伤了谁来负这个责任？整个一个夏天都在备战和比赛，为国效力是我的最高使命，而我只是很单纯的希望我的脚可以在比赛中得到保护。', 'attitudes': 5443, 'comments': 4746, 'reposts': 364}
# Saved to Mongo
# {'id': '4018631899553879', 'text': '老板6.8折有点低了吧！', 'attitudes': 1459, 'comments': 933, 'reposts': 22}
# Saved to Mongo
# {'id': '4000025271022668', 'text': '我在河南出生，9岁就去了辽宁的体校。小时候一直觉得出国打球的机会只属于那些遥不可及的篮球明星。现在，我给自己赢得了一个去美国休斯顿打球的机会。@NIKE #JustDoIt#', 'attitudes': 10343, 'comments': 13126, 'reposts': 345}
# Saved to Mongo
